# %%
import requests
from bs4 import BeautifulSoup
import json
import ast

# %% [markdown]
# ### Khan Academy

# %%
r = requests.get("http://www.khanacademy.org/api/v1/topic/computing")

# %%
soup = BeautifulSoup(r.content,'lxml')

# %%
d = json.loads(soup.body.p.text)
print(d['children'][1])
# Out:
# {'description': 'Learn select topics from computer science - algorithms (how we solve common problems in computer science and measure the efficiency of our solutions), cryptography (how we protect secret information), and information theory (how we encode and compress information).', 'internal_id': 'x301707a0', 'node_slug': 'computer-science', 'icon_large': 'https://cdn.kastatic.org/genfiles/topic-icons/icons/computer_programming.png-7da73e-416.png', 'key': 'ag5zfmtoYW4tYWNhZGVteXIUCxIFVG9waWMiCXgzMDE3MDdhMAw', 'translated_title': 'Computer science', 'id': 'computer-science', 'icon': 'https://cdn.kastatic.org/genfiles/topic-icons/icons/computer_programming.png-7da73e-128c.png', 'kind': 'Topic', 'hide': False, 'relative_url': '/computing/computer-science', 'title': 'Computer science', 'url': 'https://www.khanacademy.org/computing/computer-science', 'edit_slug': '', 'translated_description': 'Learn select topics from computer science - algorithms (how we solve common problems in comput
# ...

# %% [markdown]
# ### Udemy

# %%
headers = {"Authorization": "Basic ak9uRVliaFh1eHlKeFl4UXl0WTEzcm1MWHF5a01ldk96QldqNFZiTjpTZUtienJESFdyd3UyUEEzaWI3UDgwanBZYlVZd2pCMGdHcDZ2OGowVmVjNmdVc3dGd1NvRkxHWjZRYVVFZHI2NldHdnhKdzZTdDFzbkRWRzA0aU9wb0NvbDVFbkxORE1wQWNlRkJ1bnl2OUJxQ3Z6NmJtRWthbGplOGJIakNIYw==",
  "Accept": "application/json, text/plain, */*"}
r = requests.get("https://www.udemy.com/api-2.0/courses/?page=28&page_size=100",headers = headers)

# %%
soup= BeautifulSoup(r.text,'lxml')

# %%
json.loads(soup.body.p.text)['next']
# Out:
# 'https://www.udemy.com/api-2.0/courses/?page=29&page_size=100'

# %%
soup
# Out:
# <html><body><p>{"count": 52440, "next": "https://www.udemy.com/api-2.0/courses/?page=29&amp;page_size=100", "previous": "https://www.udemy.com/api-2.0/courses/?page=27&amp;page_size=100", "results": [{"_class": "course", "id": 597442, "title": "JavaScript AJAX PHP mySQL create a Dynamic web Form project", "url": "/javascript-ajax-php-mysql-create-a-comment-submission-form/", "is_paid": true, "price": "$104.99", "visible_instructors": [{"_class": "user", "id": 5581552, "title": "Laurence Svekis", "name": "Laurence", "display_name": "Laurence Svekis", "job_title": "Instructor, 18+yrs Web Experience", "image_50x50": "https://udemy-images.udemy.com/user/50x50/5581552_b409_15.jpg", "image_100x100": "https://udemy-images.udemy.com/user/100x100/5581552_b409_15.jpg", "initials": "LS", "url": "/user/lars51/"}], "image_125_H": "https://udemy-images.udemy.com/course/125_H/597442_1b1f_4.jpg", "image_240x135": "https://udemy-images.udemy.com/course/240x135/597442_1b1f_4.jpg", "is_practice_test_co
# ...

# %%
udemy_info = {
    'Course': [],
    'Price': [],
    'Description': [],
    'Instructor': [],
    'Link': [],
    'Image': []
}

# %%
def getUdemyDescription(url):
    user_header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}
    url = 'http://udemy.com' + url
    req = requests.get(url,headers = user_header)
    soup = BeautifulSoup(req.text,'lxml')
    
    description = soup.body.find("div",class_ = "clp-lead__headline").text
    return description.strip()
    

def getUdemyInfo(entry,udemy_info):
    assert entry['_class'] == 'course'
    
    udemy_info['Course'].append(entry['title'])
    udemy_info['Price'].append(entry['price'])
    udemy_info['Link'].append(entry['url'])
    if len(entry['visible_instructors']) != 0:
        udemy_info['Instructor'].append(entry['visible_instructors'][0]['title'])
    udemy_info['Image'].append(entry['image_125_H'])
    udemy_info['Description'].append(getUdemyDescription(entry['url']))

# %%
url = "https://www.udemy.com/api-2.0/courses/"
while True:
    print(url)
    r = requests.get(url,headers = headers)
    soup= BeautifulSoup(r.text,'lxml')
    url = json.loads(soup.body.p.text)['next']
    results = json.loads(soup.body.p.text)['results']
    for entry in results:
        getUdemyInfo(entry,udemy_info)
# Out:
# https://www.udemy.com/api-2.0/courses/
# https://www.udemy.com/api-2.0/courses/?page=2&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=3&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=4&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=5&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=6&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=7&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=8&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=9&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=10&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=11&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=12&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=13&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=14&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=15&page_size=12
# https://www.udemy.com/api-2.0/courses/?page=16&page_size=12
# ...

# %%
udemy_info
# Out:
# {'Course': ['JavaScript: Understanding the Weird Parts',
#   'Learn and Understand AngularJS',
#   "Webpack 2: The Complete Developer's Guide",
#   'Blockchain and Bitcoin Fundamentals',
#   'Build Responsive Real World Websites with HTML5 and CSS3',
#   'Reiki Level I, II and Master/Teacher Program',
#   'C# Advanced Topics: Take Your C# Skills to the Next Level',
#   'C# Intermediate: Classes, Interfaces and OOP',
#   'Cryptocurrency ICO Investing Course 2018: Identify the Best!',
#   "ES6 Javascript: The Complete Developer's Guide",
#   'R Programming: Advanced Analytics In R For Data Science',
#   'Become A Learning Machine 2.0: Read 300 Books This Year',
#   'Crystal Reiki Master/Teacher Certification',
#   'eBay Drop Shipping Guide with No Inventory - Work From Home',
#   'Understanding TypeScript',
#   'C# Basics for Beginners: Learn C# Fundamentals by Coding',
#   'Learn and Understand NodeJS',
#   'The Complete SQL Bootcamp',
# ...

# %%
import pandas as pd

# %%
for key in udemy_info:
    print(key, len(udemy_info[key]))
# Out:
# Course 212
# Subject 0
# Price 212
# Description 211
# Instructor 212
# Link 212
# Image 212

# %%
json.loads(soup.body.p.text)['results'][0]
# Out:
# {'_class': 'course',
#  'id': 1405632,
#  'image_125_H': 'https://udemy-images.udemy.com/course/125_H/1405632_6e6f.jpg',
#  'image_240x135': 'https://udemy-images.udemy.com/course/240x135/1405632_6e6f.jpg',
#  'image_480x270': 'https://udemy-images.udemy.com/course/480x270/1405632_6e6f.jpg',
#  'input_features': None,
#  'is_paid': True,
#  'is_practice_test_course': False,
#  'lecture_search_result': None,
#  'predictive_score': None,
#  'price': '$194.99',
#  'published_title': 'sql-mysql-for-data-analytics-and-business-intelligence',
#  'relevancy_score': 1.0666366,
#  'title': 'SQL - MySQL for Data Analytics and Business Intelligence',
#  'url': '/sql-mysql-for-data-analytics-and-business-intelligence/',
#  'visible_instructors': [{'_class': 'user',
#    'display_name': '365 Careers',
#    'id': 8280056,
#    'image_100x100': 'https://udemy-images.udemy.com/user/100x100/8280056_7887_3.jpg',
#    'image_50x50': 'https://udemy-images.udemy.com/user/50x50/8280056_7887_3.jpg',
# ...

# %%
r = requests.get("https://www.udemy.com/api-2.0/courses/?language",headers = headers)

# %%
udemy_info['Course'].append("hi")
udemy_info['Description'].append("hi")
udemy_info['Image'].append("hi")
udemy_info['Instructor'].append("hi")
udemy_info['Link'].append("hi")
udemy_info['Price'].append("hi")

# %%
df = pd.DataFrame.from_dict(udemy_info)

# %%
df.to_csv("hi.csv")
